# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
dataframe_1 = pd.read_csv('C:\\Users\\Nimisha Jain\\Downloads\\Archigos_ A Database of Political Leaders - 1March_Archigos_4.1.csv')

# %%
dataframe_1.columns
# Out:
# Index(['obsid', 'leadid', 'ccode', 'idacr', 'leader', 'startdate', 'enddate',
#        'entry', 'exit', 'exitcode', 'prevtimesinoffice', 'posttenurefate',
#        'gender', 'yrborn', 'yrdied', 'borndate', 'deathdate', 'dbpedia.uri',
#        'num.entry', 'num.exit', 'num.exitcode', 'num.posttenurefate', 'fties',
#        'ftcur'],
#       dtype='object')

# %%
dataframe_1.head()
# Out:
#       obsid                                leadid  ccode idacr  \
# 0  ECU-1869  3539f318-3bbd-11e5-afeb-eb6f07f9fec7    130   ECU
# 1  HAI-1874  81df6d19-1e42-11e4-b4cd-db5882bf8def     41   HAI
# 2  LBR-1872  197863a8-3bbd-11e5-afeb-eb6f07f9fec7    450   LBR
# 3  TUR-1861  823ce4cd-1e42-11e4-b4cd-db5882bf8def    640   TUR
# 4  PAR-1874  81fe84c0-1e42-11e4-b4cd-db5882bf8def    150   PAR
#
#                    leader   startdate     enddate      entry  \
# 0   Gabriel García Moreno  1869-01-19  1875-08-06  Irregular
# 1                  Rameau  1874-06-11  1876-04-15  Irregular
# 2  Joseph Jenkins Roberts  1872-01-01  1875-06-27  Irregular
# 3              Abdul Aziz  1861-06-25  1876-05-30    Regular
# 4                    Gill  1874-11-25  1877-04-12  Irregular
#
#                         exit                                      exitcode  \
# 0                  Irregular                                       Unknown
# ...

# %%
data_filter1 = dataframe_1.fillna(0)

# %%
data_filter1
# Out:
#            obsid                                leadid  ccode idacr  \
# 0       ECU-1869  3539f318-3bbd-11e5-afeb-eb6f07f9fec7    130   ECU
# 1       HAI-1874  81df6d19-1e42-11e4-b4cd-db5882bf8def     41   HAI
# 2       LBR-1872  197863a8-3bbd-11e5-afeb-eb6f07f9fec7    450   LBR
# 3       TUR-1861  823ce4cd-1e42-11e4-b4cd-db5882bf8def    640   TUR
# 4       PAR-1874  81fe84c0-1e42-11e4-b4cd-db5882bf8def    150   PAR
# 5       CHL-1871  81ffda8d-1e42-11e4-b4cd-db5882bf8def    155   CHL
# 6       NEP-1846  8249dd62-1e42-11e4-b4cd-db5882bf8def    790   NEP
# 7     DOM-1876-2  81e0f3c2-1e42-11e4-b4cd-db5882bf8def     42   DOM
# 8     VEN-1877-2  81f52bf9-1e42-11e4-b4cd-db5882bf8def    101   VEN
# 9       PER-1872  81f89af9-1e42-11e4-b4cd-db5882bf8def    135   PER
# 10      SWZ-1875  820d967e-1e42-11e4-b4cd-db5882bf8def    225   SWZ
# 11      MYA-1853  82491a13-1e42-11e4-b4cd-db5882bf8def    775   MYA
# 12      SWZ-1877  820d967f-1e42-11e4-b4cd-db5882bf8def    225   SWZ
# ...

# %%
final_data = data_filter1[(data_filter1.borndate != 0) & (data_filter1.deathdate != 0) ]

# %%
final_data
# Out:
#            obsid                                leadid  ccode idacr  \
# 0       ECU-1869  3539f318-3bbd-11e5-afeb-eb6f07f9fec7    130   ECU
# 6       NEP-1846  8249dd62-1e42-11e4-b4cd-db5882bf8def    790   NEP
# 11      MYA-1853  82491a13-1e42-11e4-b4cd-db5882bf8def    775   MYA
# 18      UKG-1874  1975cb98-3bbd-11e5-afeb-eb6f07f9fec7    200   UKG
# 22      RUS-1855  822047fc-1e42-11e4-b4cd-db5882bf8def    365   RUS
# 31      FRN-1881  820bae28-1e42-11e4-b4cd-db5882bf8def    220   FRN
# 39    DOM-1876-4  81de4823-1e42-11e4-b4cd-db5882bf8def     42   DOM
# 88    SWZ-1888-1  820df822-1e42-11e4-b4cd-db5882bf8def    225   SWZ
# 89      GMY-1858  82131e92-1e42-11e4-b4cd-db5882bf8def    255   GMY
# 93      MEX-1872  81e39f70-1e42-11e4-b4cd-db5882bf8def     70   MEX
# 106     BRA-1840  81fab41b-1e42-11e4-b4cd-db5882bf8def    140   BRA
# 126     SWD-1883  8224dbfe-1e42-11e4-b4cd-db5882bf8def    380   SWD
# 143     COL-1880  81f3a54e-1e42-11e4-b4cd-db5882bf8def    100   COL
# ...

# %%
final_data['age'] = (final_data.yrdied) - (final_data.yrborn)
# Out:
# C:\Users\Nimisha Jain\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
final_data1 = final_data[final_data.age > 0]

# %%
final_data1
# Out:
#            obsid                                leadid  ccode idacr  \
# 0       ECU-1869  3539f318-3bbd-11e5-afeb-eb6f07f9fec7    130   ECU
# 6       NEP-1846  8249dd62-1e42-11e4-b4cd-db5882bf8def    790   NEP
# 11      MYA-1853  82491a13-1e42-11e4-b4cd-db5882bf8def    775   MYA
# 18      UKG-1874  1975cb98-3bbd-11e5-afeb-eb6f07f9fec7    200   UKG
# 22      RUS-1855  822047fc-1e42-11e4-b4cd-db5882bf8def    365   RUS
# 31      FRN-1881  820bae28-1e42-11e4-b4cd-db5882bf8def    220   FRN
# 39    DOM-1876-4  81de4823-1e42-11e4-b4cd-db5882bf8def     42   DOM
# 88    SWZ-1888-1  820df822-1e42-11e4-b4cd-db5882bf8def    225   SWZ
# 89      GMY-1858  82131e92-1e42-11e4-b4cd-db5882bf8def    255   GMY
# 93      MEX-1872  81e39f70-1e42-11e4-b4cd-db5882bf8def     70   MEX
# 106     BRA-1840  81fab41b-1e42-11e4-b4cd-db5882bf8def    140   BRA
# 126     SWD-1883  8224dbfe-1e42-11e4-b4cd-db5882bf8def    380   SWD
# 143     COL-1880  81f3a54e-1e42-11e4-b4cd-db5882bf8def    100   COL
# ...

# %%
import seaborn as sns
box_plot = sns.catplot(data = final_data1, x = "yrdied", y = "age",kind='box',size=18)
box_plot.set_xticklabels(rotation=90)
# Out:
# C:\Users\Nimisha Jain\Anaconda3\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
